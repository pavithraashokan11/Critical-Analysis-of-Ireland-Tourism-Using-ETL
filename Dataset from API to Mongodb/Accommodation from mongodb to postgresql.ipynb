# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
client = MongoClient('mongodb://root:rootpassword@localhost:27017/')
db = client['IRL']

#Creating a new collection 
collection=db.Accommodation
acm=pd.DataFrame(list(collection.find()))
acm.head(10)
# Out:
#                         _id           @context  \
# 0  6446620c9b0c5d98bfb34639  http://schema.org
# 1  6446620c9b0c5d98bfb3463a  http://schema.org
# 2  6446620c9b0c5d98bfb3463b  http://schema.org
# 3  6446620c9b0c5d98bfb3463c  http://schema.org
# 4  6446620c9b0c5d98bfb3463d  http://schema.org
# 5  6446620c9b0c5d98bfb3463e  http://schema.org
# 6  6446620c9b0c5d98bfb3463f  http://schema.org
# 7  6446620c9b0c5d98bfb34640  http://schema.org
# 8  6446620c9b0c5d98bfb34641  http://schema.org
# 9  6446620c9b0c5d98bfb34642  http://schema.org
#
#                               @type                             name  \
# 0            [Hotel, LocalBusiness]                    Taravie Hotel
# 1            [Hotel, LocalBusiness]  Adare Manor Hotel & Golf Resort
# 2           [Hostel, LocalBusiness]         Courtbrack Accommodation
# 3  [BedAndBreakfast, LocalBusiness]                       Glencarrig
# 4  [BedAndBreakfast, LocalBusiness]                     Mevagh House
# 5  [BedAndBreakfast, LocalBusiness]                    Cul Draiochta
# 6  [BedAndBreakfast, LocalBusiness]               Templecarrig House
# 7  [BedAndBreakfast, LocalBusiness]                    Cuaneen House
# 8  [LodgingBusiness, LocalBusiness]                  Ashwell Cottage
# 9  [BedAndBreakfast, LocalBusiness]                   Killurin Lodge
#
#                                                  url  \
# 0  https://www.facebook.com/pages/Taravie-Hotel/2...
# 1                        https://www.adaremanor.com/
# 2
# 3                https://www.facebook.com/glencarrig
# 4                         http://www.mevaghhouse.com
# 5
# 6                 https://www.templecarrighouse.com/
# 7                        http://www.cuaneenhouse.com
# 8                      http://www.ashwellcottage.com
# 9                       http://www.killurinlodge.com
#
#                                                  geo         telephone  \
# 0  {'@type': 'GeoCoordinates', 'longitude': -6.22...  +353(0)539425208
# 1  {'@type': 'GeoCoordinates', 'longitude': -8.77...      +35361605200
# 2  {'@type': 'GeoCoordinates', 'longitude': -8.64...   +353(0)61302500
# 3  {'@type': 'GeoCoordinates', 'longitude': -9.72...  +353(0)659058209
# 4  {'@type': 'GeoCoordinates', 'longitude': -7.78...  +353(0)749154708
# 5  {'@type': 'GeoCoordinates', 'longitude': -10.2...  +353(0)669473141
# 6  {'@type': 'GeoCoordinates', 'longitude': -9.22...     +353949546818
# 7  {'@type': 'GeoCoordinates', 'longitude': -9.82...    +353(0)9866460
# 8  {'@type': 'GeoCoordinates', 'longitude': -6.61...      +35345879167
# 9  {'@type': 'GeoCoordinates', 'longitude': -6.57...  +353(0)539128013
#
#                                              address  \
# 0  {'@type': 'PostalAddress', 'addressLocality': ...
# 1  {'@type': 'PostalAddress', 'addressLocality': ...
# 2  {'@type': 'PostalAddress', 'addressLocality': ...
# 3  {'@type': 'PostalAddress', 'addressLocality': ...
# 4  {'@type': 'PostalAddress', 'addressLocality': ...
# 5  {'@type': 'PostalAddress', 'addressLocality': ...
# 6  {'@type': 'PostalAddress', 'addressLocality': ...
# 7  {'@type': 'PostalAddress', 'addressLocality': ...
# 8  {'@type': 'PostalAddress', 'addressLocality': ...
# 9  {'@type': 'PostalAddress', 'addressLocality': ...
#
#                                                image  \
# 0  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 1  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 2  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 3  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 4  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 5  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 6  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 7  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 8  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 9  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
#
#                                                 tags
# 0  [Accommodation, Hotel, Follow the Shamrock, St...
# 1  [Accommodation, Hotel, Follow the Shamrock, St...
# 2  [Accommodation, Hostel, Follow the Shamrock, S...
# 3  [Accommodation, B&B, Follow the Shamrock, Stan...
# 4  [Accommodation, B&B, Follow the Shamrock, Stan...
# 5  [Accommodation, B&B, Follow the Shamrock, Stan...
# 6  [Accommodation, B&B, Follow the Shamrock, Stan...
# 7  [Accommodation, B&B, Follow the Shamrock, Stan...
# 8  [Accommodation, Self Catering Accommodation, F...
# 9  [Accommodation, B&B, Follow the Shamrock, Stan...

# %%
acm=acm.drop(['_id','@context','image',], axis=1)

# %%
acm.head()
# Out:
#                               @type                             name  \
# 0            [Hotel, LocalBusiness]                    Taravie Hotel
# 1            [Hotel, LocalBusiness]  Adare Manor Hotel & Golf Resort
# 2           [Hostel, LocalBusiness]         Courtbrack Accommodation
# 3  [BedAndBreakfast, LocalBusiness]                       Glencarrig
# 4  [BedAndBreakfast, LocalBusiness]                     Mevagh House
#
#                                                  url  \
# 0  https://www.facebook.com/pages/Taravie-Hotel/2...
# 1                        https://www.adaremanor.com/
# 2
# 3                https://www.facebook.com/glencarrig
# 4                         http://www.mevaghhouse.com
#
#                                                  geo         telephone  \
# 0  {'@type': 'GeoCoordinates', 'longitude': -6.22...  +353(0)539425208
# 1  {'@type': 'GeoCoordinates', 'longitude': -8.77...      +35361605200
# 2  {'@type': 'GeoCoordinates', 'longitude': -8.64...   +353(0)61302500
# 3  {'@type': 'GeoCoordinates', 'longitude': -9.72...  +353(0)659058209
# 4  {'@type': 'GeoCoordinates', 'longitude': -7.78...  +353(0)749154708
#
#                                              address  \
# 0  {'@type': 'PostalAddress', 'addressLocality': ...
# 1  {'@type': 'PostalAddress', 'addressLocality': ...
# 2  {'@type': 'PostalAddress', 'addressLocality': ...
# 3  {'@type': 'PostalAddress', 'addressLocality': ...
# 4  {'@type': 'PostalAddress', 'addressLocality': ...
#
#                                                 tags
# 0  [Accommodation, Hotel, Follow the Shamrock, St...
# 1  [Accommodation, Hotel, Follow the Shamrock, St...
# 2  [Accommodation, Hostel, Follow the Shamrock, S...
# 3  [Accommodation, B&B, Follow the Shamrock, Stan...
# 4  [Accommodation, B&B, Follow the Shamrock, Stan...

# %%
Name = acm['name'].tolist()
City = acm['address'].apply(lambda x: x['addressLocality']).tolist()
County = acm['address'].apply(lambda x: x['addressRegion']).tolist()
Country = acm['address'].apply(lambda x: x['addressCountry']).tolist()
Latitudes = acm['geo'].apply(lambda x: x['latitude']).tolist()
Longitudes = acm['geo'].apply(lambda x: x['longitude']).tolist()
URL = acm['url'].tolist()
Telephone= acm['telephone'].tolist()
Tags= acm['tags'].tolist()
type_of_place=pd.DataFrame(columns=['Type of Activity'])

for data in acm["tags"]:
    if len(data) >= 2:
        Tags.append(data[1])
    else:
        Tags.append(data[0])
type_of_place['Type of Venue'] = Tags

# %%
Tag = []
for i in range(len(Tags)):
    for j in range(len(Tags[i])):
        if j % 2 != 0:
            Tag.append(Tags[i][j])

print(Tag)
# Out:
# ['Hotel', 'Standard', 'Hotel', 'Standard', 'Hostel', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'Self Catering Accommodation', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'Hotel', 'Standard', 'Self Catering Accommodation', 'Standard', 'B&B', 'Standard', 'Self Catering Accommodation', 'B&B', 'Self Catering Accommodation', 'Hostel', 'Standard', 'B&B', 'Standard', 'Camping', 'Standard', 'B&B', 'Hostel', 'Standard', 'B&B', 'Hostel', 'Standard', 'Self Catering Accommodation', 'Self Catering Accommodation', 'Standard', 'Self Catering Accommodation', 'Hotel', 'Standard', 'B&B', 'Standard', 'Self Catering Accommodation', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Self Catering Accommodation', 'Hostel', 'B&B', "Ireland's Hidden Hearthlands", 'Historic House', 'Self Catering Accommodation', 'Standard', 'B&B', 'Hotel', 'Camping', 'Standard', 'Hotel', 'Standard', 'Guesthouse', 'Standard', 'Self Catering Accommodation', "Ireland's Hidden Hearthlands", 'Self Catering Accommodation', "Ireland's Hidden Hearthlands", 'B&B', 'Standard', 'Hostel', 'Self Catering Accommodation', 'Self Catering Accommodation', 'Self Catering Accommodation', 'B&B', "Ireland's Hidden Hearthlands", 'B&B', 'Hotel', 'Standard', 'Hostel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'Historic House', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'Self Catering Accommodation', 'Standard', 'Camping', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'B&B', 'Standard', 'Hotel', 'Standard', 'B&B', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Self Catering Accommodation', 'B&B', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Camping', 'Standard', 'B&B', 'Hotel', 'Standard', 'Self Catering Accommodation', 'Hostel', 'Self Catering Accommodation', 'Standard', 'Self Catering Accommodation', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Guesthouse', 'Standard', 'Guesthouse', 'Standard', 'Hotel', 'Standard', 'Guesthouse', 'Standard', 'Hotel', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'Historic House', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'Guesthouse', 'Standard', 'Guesthouse', 'Standard', 'Guesthouse', 'Standard', 'Guesthouse', 'Standard', 'Guesthouse', 'Standard', 'Guesthouse', 'Standard', 'Self Catering Accommodation', 'Self Catering Accommodation', 'Self Catering Accommodation', 'Standard', 'Self Catering Accommodation', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'B&B', 'Standard', 'Hotel', 'Standard', 'Guesthouse', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Self Catering Accommodation', 'Self Catering Accommodation', 'B&B', 'Standard', 'Self Catering Accommodation', 'Camping', 'Glamping', 'Hotel', 'Standard', 'Hostel', 'Standard', 'Hotel', 'Standard', 'B&B', 'Standard', 'B&B', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Self Catering Accommodation', 'B&B', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Hotel',  ...

# %%
Type= [] 
type_of=pd.DataFrame(columns=['Type of Venue'])

for data in acm["@type"]:
    if len(data) >= 2:
        Type.append(data[1])
    else:
        Type.append(data[0])
type_of['Type of Venue'] = Type

# %%
import psycopg2

conn = psycopg2.connect("postgresql://admin:secret@127.0.0.1:5432/Tourism")

# %%
cur = conn.cursor()

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

conn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
cur.execute("SELECT current_database()")

cur.fetchone()
# Out:
# ('Tourism',)

# %%
cur.execute("DROP TABLE IF EXISTS accommodation")

# %%
cur.execute('''CREATE TABLE IF NOT EXISTS accommodation
               (Name varchar(80), Type varchar(40), City varchar(80), County varchar(80), Country varchar(80), Latitude DOUBLE PRECISION,
               Longitude DOUBLE PRECISION, Tag varchar(40));''')

# %%
for i in range(len(Name)):
    cur.execute(
        "INSERT INTO accommodation (Name, Type, City, County, country, Latitude, Longitude, Tag) VALUES (%s, %s, %s, %s, %s, %s, %s,%s)",
        (Name[i][:80], Type[i], City[i], County[i], Country[i], Latitudes[i], Longitudes[i],Tag[i])
    )
