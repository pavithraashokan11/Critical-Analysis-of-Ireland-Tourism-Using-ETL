# %% [markdown]
# # Establishing connection to MongoDB

# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
client = MongoClient('mongodb://root:rootpassword@localhost:27017/')
db = client['IRL']

#Creating a new collection 
collection=db.Accommodation
acm=pd.DataFrame(list(collection.find()))
acm.head(10)
# Out:
#                         _id           @context  \
# 0  6457ebaed284eb9234e5f036  http://schema.org
# 1  6457ebaed284eb9234e5f037  http://schema.org
# 2  6457ebaed284eb9234e5f038  http://schema.org
# 3  6457ebaed284eb9234e5f039  http://schema.org
# 4  6457ebaed284eb9234e5f03a  http://schema.org
# 5  6457ebaed284eb9234e5f03b  http://schema.org
# 6  6457ebaed284eb9234e5f03c  http://schema.org
# 7  6457ebaed284eb9234e5f03d  http://schema.org
# 8  6457ebaed284eb9234e5f03e  http://schema.org
# 9  6457ebaed284eb9234e5f03f  http://schema.org
#
#                               @type                             name  \
# 0            [Hotel, LocalBusiness]                    Taravie Hotel
# 1            [Hotel, LocalBusiness]  Adare Manor Hotel & Golf Resort
# 2           [Hostel, LocalBusiness]         Courtbrack Accommodation
# 3  [BedAndBreakfast, LocalBusiness]                       Glencarrig
# 4  [BedAndBreakfast, LocalBusiness]                     Mevagh House
# ...

# %%
acm=acm.drop(['_id','@context','image',], axis=1)

# %%
acm.head()
# Out:
#                               @type                             name  \
# 0            [Hotel, LocalBusiness]                    Taravie Hotel
# 1            [Hotel, LocalBusiness]  Adare Manor Hotel & Golf Resort
# 2           [Hostel, LocalBusiness]         Courtbrack Accommodation
# 3  [BedAndBreakfast, LocalBusiness]                       Glencarrig
# 4  [BedAndBreakfast, LocalBusiness]                     Mevagh House
#
#                                                  url  \
# 0  https://www.facebook.com/pages/Taravie-Hotel/2...
# 1                        https://www.adaremanor.com/
# 2
# 3                https://www.facebook.com/glencarrig
# 4                         http://www.mevaghhouse.com
#
#                                                  geo         telephone  \
# 0  {'@type': 'GeoCoordinates', 'longitude': -6.22...  +353(0)539425208
# 1  {'@type': 'GeoCoordinates', 'longitude': -8.77...      +35361605200
# ...

# %%
acm.tags
# Out:
# 0       [Accommodation, Hotel, Follow the Shamrock, St...
# 1       [Accommodation, Hotel, Follow the Shamrock, St...
# 2       [Accommodation, Hostel, Follow the Shamrock, S...
# 3       [Accommodation, B&B, Follow the Shamrock, Stan...
# 4       [Accommodation, B&B, Follow the Shamrock, Stan...
#                               ...
# 2257    [Accommodation, Hotel, Follow the Shamrock, St...
# 2258    [Accommodation, Self Catering Accommodation, W...
# 2259    [Accommodation, Hotel, Follow the Shamrock, St...
# 2260    [Accommodation, B&B, Follow the Shamrock, Stan...
# 2261    [Accommodation, Self Catering Accommodation, W...
# Name: tags, Length: 2262, dtype: object

# %%
Name = acm['name'].tolist()
City = acm['address'].apply(lambda x: x['addressLocality']).tolist()
County = acm['address'].apply(lambda x: x['addressRegion']).tolist()
Country = acm['address'].apply(lambda x: x['addressCountry']).tolist()
Latitudes = acm['geo'].apply(lambda x: x['latitude']).tolist()
Longitudes = acm['geo'].apply(lambda x: x['longitude']).tolist()
URL = acm['url'].tolist()
Telephone= acm['telephone'].tolist()
Tags= acm['tags'].tolist()
type_of_place=pd.DataFrame(columns=['Type of Activity'])

for data in acm["tags"]:
    if len(data) >= 2:
        Tags.append(data[1])
    else:
        Tags.append(data[0])
type_of_place['Type of Venue'] = Tags

# %%
acm
# Out:
#                                              @type  \
# 0                           [Hotel, LocalBusiness]
# 1                           [Hotel, LocalBusiness]
# 2                          [Hostel, LocalBusiness]
# 3                 [BedAndBreakfast, LocalBusiness]
# 4                 [BedAndBreakfast, LocalBusiness]
# ...                                            ...
# 2257                        [Hotel, LocalBusiness]
# 2258  [LodgingBusiness, LocalBusiness, Campground]
# 2259                        [Hotel, LocalBusiness]
# 2260              [BedAndBreakfast, LocalBusiness]
# 2261  [LodgingBusiness, LocalBusiness, Campground]
#
#                                  name  \
# 0                       Taravie Hotel
# 1     Adare Manor Hotel & Golf Resort
# 2            Courtbrack Accommodation
# 3                          Glencarrig
# 4                        Mevagh House
# ...                               ...
# 2257             Greenway Manor Hotel
# ...

# %%
Tag = []
for i in range(len(Tags)):
    for j in range(len(Tags[i])):
        if j % 2 != 0:
            Tag.append(Tags[i][j])

print(Tag)
# Out:
# ['Hotel', 'Standard', 'Hotel', 'Standard', 'Hostel', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'Self Catering Accommodation', 'Standard', 'B&B', 'Standard', 'B&B', 'Standard', 'Hotel', 'Standard', 'Self Catering Accommodation', 'Standard', 'B&B', 'Standard', 'Self Catering Accommodation', 'B&B', 'Self Catering Accommodation', 'Hostel', 'Standard', 'B&B', 'Standard', 'Camping', 'Standard', 'B&B', 'Hostel', 'Standard', 'B&B', 'Hostel', 'Standard', 'Self Catering Accommodation', 'Self Catering Accommodation', 'Standard', 'Self Catering Accommodation', 'Hotel', 'Standard', 'B&B', 'Standard', 'Self Catering Accommodation', 'Hotel', 'Standard', 'Hotel', 'Standard', 'Self Catering Accommodation', 'Hostel', 'B&B', "Ireland's Hidden Hearthlands", 'Historic House', 'B&B', 'Self Catering Accommodation', 'Standard', 'Hotel', 'Camping', 'Standard', 'Hotel', 'Standard', 'Guesthouse', 'Standard', 'Self Catering Accommodation', "Irelan
# ...

# %%
Type= [] 
type_of=pd.DataFrame(columns=['Type of Venue'])

for data in acm["@type"]:
    if len(data) >= 2:
        Type.append(data[1])
    else:
        Type.append(data[0])
type_of['Type of Venue'] = Type

# %% [markdown]
# # Connecting to PostgreSQL

# %%
import psycopg2

conn = psycopg2.connect("postgresql://admin:secret@127.0.0.1:5432/Tourism")

# %%
cur = conn.cursor()

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

conn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
cur.execute("SELECT current_database()")

cur.fetchone()
# Out:
# ('Tourism',)

# %%
cur.execute("DROP TABLE IF EXISTS accommodation")

# %%
cur.execute('''CREATE TABLE IF NOT EXISTS accommodation
               (Name varchar(80), Type varchar(40), City varchar(80), County varchar(80), Country varchar(80), Latitude DOUBLE PRECISION,
               Longitude DOUBLE PRECISION, Tag varchar(40));''')

# %%
for i in range(len(Name)):
    cur.execute(
        "INSERT INTO accommodation (Name, Type, City, County, country, Latitude, Longitude, Tag) VALUES (%s, %s, %s, %s, %s, %s, %s,%s)",
        (Name[i][:80], Type[i], City[i], County[i], Country[i], Latitudes[i], Longitudes[i],Tag[i])
    )

# %%
pip install PrettyTable
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from prettytable import PrettyTable

table = PrettyTable()
table.field_names = ['Name', 'Type', 'City', 'County', 'Country', 'Latitude', 'Longitude', 'Tag']

# Set max_width attribute to a high value to prevent truncation
table.max_width = 13

cur.execute("SELECT * FROM accommodation")
rows = cur.fetchall()

for row in rows:
    table.add_row(row)

print(table)
# Out:
# +---------------+---------------+---------------+-----------+---------------+---------------+---------------+---------------+
# |      Name     |      Type     |      City     |   County  |    Country    |    Latitude   |   Longitude   |      Tag      |
# +---------------+---------------+---------------+-----------+---------------+---------------+---------------+---------------+
# | Taravie Hotel | LocalBusiness |    Courtown   |  Wexford  |  Republic of  | 52.6453261952 | -6.2280376061 |     Hotel     |
# |               |               |               |           |    Ireland    |      866      |      5159     |               |
# |  Adare Manor  | LocalBusiness |     Adare     |  Limerick |  Republic of  |   52.5641886  |   -8.7778256  |    Standard   |
# |  Hotel & Golf |               |               |           |    Ireland    |               |               |               |
# ...
